# %% [markdown]
# # Webscraper

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests 
from bs4 import BeautifulSoup
import re
import itertools
import time


sns.set()

# %% [markdown]
# ## Scrape Data

# %%
tournament_url = 'https://www.vlr.gg/event/matches/1657/valorant-champions-2023/?series_id=all'

# %%
def scrape_game(soup, game_id):
    """
    Scrapes game information from a BeautifulSoup object based on the provided game ID.

    Parameters:
    - soup (BeautifulSoup): A BeautifulSoup object containing the HTML content of a web page.
    - game_id (str): The unique identifier for the game being scraped.

    Returns:
    - tuple: A tuple containing two lists. The first list contains map titles, and the second list contains agent names.

    The function extracts information about a single Valorant game, including the map title and character names, based on the provided
    game ID from vlr.gg. It uses the BeautifulSoup library to parse HTML content and regular expressions for pattern matching.

    The map title is extracted from a <span> element with a specific style attribute within the game's HTML content.
    Character names are extracted from multiple <span> elements with a specific class attribute.

    Example:
    >>> from bs4 import BeautifulSoup
    >>> html_content = "<div class='vm-stats-game' data-game-id='123'>...</div>"
    >>> soup = BeautifulSoup(html_content, 'html.parser')
    >>> map_title, characters = scrape_game(soup, '123')
    >>> print(map_title)
    ['MapName', 'MapName', ...]
    >>> print(characters)
    ['Character1', 'Character2', ...]
    """
    game_soup = soup.find('div', {'class':'vm-stats-game', 'data-game-id':game_id})
    
    title_pattern = r'\b[A-Z][a-z]*\b'
    map_string = game_soup.find('span', {'style':'position: relative;'}).text
    map_title = re.findall(title_pattern, str(map_string))
    
    #Scrape character
    character_spans = game_soup.find_all('span', {'class': 'stats-sq mod-agent small'})[:10]
    characters = [img['title'] for span in character_spans for img in span]
    
    #Scrape team
    team_divs = game_soup.find_all('div', {'class': 'team-name'})
    teams = [div.text.strip() for div in team_divs for i in range(5)]
    
    map_title = map_title * len(characters)
    
    return map_title, characters, teams

# %%
def scrape_match(match_url):
    """
    Scrapes a list of game IDs from a given match URL from vlr.gg.

    Parameters:
    - match_url (str): The URL of the match page to be scraped.

    Returns:
    - tuple: A tuple containing a BeautifulSoup object representing the parsed HTML content of the match page,
      and a list of game IDs associated with the match.

    This function is designed to retrieve a list of game IDs from a match URL. It uses the requests library to fetch
    the HTML content of the specified URL and BeautifulSoup to parse the HTML. The game IDs are extracted from <div> elements
    with a specific class attribute in the HTML content.

    Example:
    >>> match_url = 'https://example.com/match/123'
    >>> soup, game_ids = scrape_match(match_url)
    >>> print(game_ids)
    ['game_id_1', 'game_id_2', ...]
    """

    html = requests.get(match_url)
    soup = BeautifulSoup(html.text, 'lxml')
    
    games = soup.find_all('div', {'class':'vm-stats-gamesnav-item js-map-switch'})
    game_ids = [game['data-game-id'] for game in games]
    
    return soup, game_ids

# %%
def scrape_tournament(tournament_url):
    """
    Scrapes a list of match IDs from a given tournament URL from vlr.gg.

    Parameters:
    - tournament_url (str): The URL of the tournament page to be scraped.

    Returns:
    - list: A list of match IDs associated with the tournament.

    This function is designed to retrieve a list of match IDs from a tournament URL. It uses the requests library to fetch
    the HTML content of the specified URL and BeautifulSoup to parse the HTML. Match IDs are extracted from the <div> elements
    with specific class and style attributes. The function also utilizes regular expressions and itertools to process the data.

    Example:
    >>> tournament_url = 'https://example.com/tournament/456'
    >>> match_ids = scrape_tournament(tournament_url)
    >>> print(match_ids)
    ['123456', '789012', ...]
    """
    html = requests.get(tournament_url)
    soup = BeautifulSoup(html.text, 'lxml')
    
    tournament_pattern = r'href="/\d+/[^"]+"'
    matches = soup.find_all('div', {'class':'wf-card', 'style':'margin-bottom: 30px;'})
    
    links = [re.findall(tournament_pattern, str(strings)) for item in matches \
         for strings in item.children if re.findall(tournament_pattern, str(strings))]
    links = list(itertools.chain(*links))
    
    match_pattern = r'\b\d{6}\b'
    match_ids = [re.findall(match_pattern,string) for string in links]
    match_ids = list(itertools.chain(*match_ids))
    
    return match_ids

# %%
def scrape_games_in_tournament():
    """
    Scrapes game data from multiple matches in a tournament from vlr.gg and returns it as a DataFrame.

    Returns:
    - pandas.DataFrame: A DataFrame containing scraped game data including map titles, character names,
      match IDs, and game IDs.

    This function orchestrates the scraping process by utilizing other functions (scrape_tournament, scrape_match,
    and scrape_game). It iterates through each match in a tournament, retrieves the relevant game and match information,
    and organizes it into a DataFrame. The scraping process involves fetching match IDs, match URLs, game IDs, map titles,
    and character names.

    Example:
    >>> scraped_data = scrape_games_in_tournament()
    >>> print(scraped_data.head())
         map         agents match_id game_id
    0    Map1    Character1  123456   789012
    1    Map1    Character2  123456   789012
    2    Map1    Character3  123456   789012
    ...  ...     ...         ...      ...
    """
    df = pd.DataFrame()
    
    match_ids = scrape_tournament(tournament_url)
    
    for n, match_id in enumerate(match_ids, start = 1):
        print(f'Scraping match {n} of {len(match_ids)}.')
        match_url = f'https://www.vlr.gg/{match_id}' 
        
        match_soup, game_ids = scrape_match(match_url)
        
        for game_id in game_ids:
            map_title, characters, teams = scrape_game(match_soup, game_id)
            
            match_list = [match_id] * len(characters)
            game_list = [game_id] * len(characters)
    
            game_df = pd.DataFrame({'map': map_title, 
                                    'agents': characters,
                                    'team' : teams,
                                    'match_id': match_list, 
                                    'game_id': game_list})
            df = df.append(game_df)

        time.sleep(2)
    
    return df

# %%
tournament_df = scrape_games_in_tournament()
# Out:
# Scraping match 1 of 34.
#         map   agents           team match_id game_id
# 0  Fracture    Viper    Team Liquid   247100  137395
# 1  Fracture   Breach    Team Liquid   247100  137395
# 2  Fracture    Astra    Team Liquid   247100  137395
# 3  Fracture     Neon    Team Liquid   247100  137395
# 4  Fracture     Sova    Team Liquid   247100  137395
# 5  Fracture    Viper  Natus Vincere   247100  137395
# 6  Fracture  Killjoy  Natus Vincere   247100  137395
# 7  Fracture     Raze  Natus Vincere   247100  137395
# 8  Fracture     Fade  Natus Vincere   247100  137395
# 9  Fracture     Omen  Natus Vincere   247100  137395
#     map     agents           team match_id game_id
# 0  Bind      Viper    Team Liquid   247100  137396
# 1  Bind       Raze    Team Liquid   247100  137396
# 2  Bind    Chamber    Team Liquid   247100  137396
# 3  Bind      Astra    Team Liquid   247100  137396
# 4  Bind       Skye    Team Liquid   247100  137396
# 5  Bind      Viper  Natus Vincere   247100  137396
# 6  Bind       Skye  Natus Vincere   247100  137396
# 7  Bind  Brimstone  Natus Vincere   247100  137396
# 8  Bind       Neon  Natus Vincere   247100  137396
# 9  Bind       Raze  Natus Vincere   247100  137396
# Scraping match 2 of 34.
#      map   agents  team match_id game_id
# 0  Lotus    Viper   DRX   247101  137398
# 1  Lotus     Fade   DRX   247101  137398
# 2  Lotus  Killjoy   DRX   247101  137398
# 3  Lotus     Omen   DRX   247101  137398
# 4  Lotus     Raze   DRX   247101  137398
# 5  Lotus     Raze  LOUD   247101  137398
# 6  Lotus     Fade  LOUD   247101  137398
# 7  Lotus    Viper  LOUD   247101  137398
# 8  Lotus  Killjoy  LOUD   247101  137398
# 9  Lotus     Omen  LOUD   247101  137398
#      map   agents  team match_id game_id
# 0  Split     Omen   DRX   247101  137399
# 1  Split     Raze   DRX   247101  137399
# 2  Split    Viper   DRX   247101  137399
# 3  Split  Killjoy   DRX   247101  137399
# 4  Split     Skye   DRX   247101  137399
# 5  Split     Raze  LOUD   247101  137399
# 6  Split  Killjoy  LOUD   247101  137399
# 7  Split    Astra  LOUD   247101  137399
# 8  Split   Breach  LOUD   247101  137399
# 9  Split     Skye  LOUD   247101  137399
#       map   agents  team match_id game_id
# 0  Ascent  Killjoy   DRX   247101  137400
# 1  Ascent     Omen   DRX   247101  137400
# 2  Ascent     Kayo   DRX   247101  137400
# 3  Ascent     Sova   DRX   247101  137400
# 4  Ascent     Jett   DRX   247101  137400
# 5  Ascent     Fade  LOUD   247101  137400
# 6  Ascent     Jett  LOUD   247101  137400
# 7  Ascent    Viper  LOUD   247101  137400
# 8  Ascent     Omen  LOUD   247101  137400
# 9  Ascent   Breach  LOUD   247101  137400
# Scraping match 3 of 34.
#      map     agents         team match_id game_id
# 0  Pearl      Viper  FUT Esports   247087  137368
# 1  Pearl    Killjoy  FUT Esports   247087  137368
# 2  Pearl       Kayo  FUT Esports   247087  137368
# 3  Pearl  Brimstone  FUT Esports   247087  137368
# 4  Pearl       Jett  FUT Esports   247087  137368
# 5  Pearl       Jett           T1   247087  137368
# 6  Pearl    Killjoy           T1   247087  137368
# 7  Pearl      Viper           T1   247087  137368
# 8  Pearl     Harbor           T1   247087  137368
# 9  Pearl       Skye           T1   247087  137368
#      map   agents         team match_id game_id
# 0  Haven     Omen  FUT Esports   247087  137369
# 1  Haven     Jett  FUT Esports   247087  137369
# 2  Haven   Breach  FUT Esports   247087  137369
# 3  Haven    Gekko  FUT Esports   247087  137369
# 4  Haven  Killjoy  FUT Esports   247087  137369
# 5  Haven   Breach           T1   247087  137369
# 6  Haven     Sova           T1   247087  137369
# 7  Haven     Omen           T1   247087  137369
# 8  Haven  Killjoy           T1   247087  137369
# 9  Haven     Jett           T1   247087  137369
# Scraping match 4 of 34.
#       map   agents             team match_id game_id
# 0  Ascent     Omen    Evil Geniuses   247086  137365
# 1  Ascent     Kayo    Evil Geniuses   247086  137365
# 2  Ascent     Jett    Evil Geniuses   247086  137365
# 3  Ascent     Sova    Evil Geniuses   247086  137365
# 4  Ascent  Killjoy    Evil Geniuses   247086  137365
# 5  Ascent     Skye  FunPlus Phoenix   247086  137365
# 6  Ascent  Killjoy  FunPlus Phoenix   247086  137365
# 7  Ascent     Jett  FunPlus Phoenix   247086  137365
# 8  Ascent    Astra  FunPlus Phoenix   247086  137365
# 9  Ascent     Omen  FunPlus Phoenix   247086  137365
#      map   agents             team match_id game_id
# 0  Pearl    Astra    Evil Geniuses   247086  137366
# 1  Pearl     Jett    Evil Geniuses   247086  137366
# 2  Pearl     Kayo    Evil Geniuses   247086  137366
# 3  Pearl     Sova    Evil Geniuses   247086  137366
# 4  Pearl  Killjoy    Evil Geniuses   247086  137366
# 5  Pearl    Astra  FunPlus Phoenix   247086  137366
# 6  Pearl     Skye  FunPlus Phoenix   247086  137366
# 7  Pearl  Killjoy  FunPlus Phoenix   247086  137366
# 8  Pearl     Jett  FunPlus Phoenix   247086  137366
# 9  Pearl     Omen  FunPlus Phoenix   247086  137366
# Scraping match 5 of 34.
#     map     agents           team match_id game_id
# 0  Bind       Skye  Natus Vincere   247102  137401
# 1  Bind       Raze  Natus Vincere   247102  137401
# 2  Bind       Sage  Natus Vincere   247102  137401
# 3  Bind      Viper  Natus Vincere   247102  137401
# 4  Bind  Brimstone  Natus Vincere   247102  137401
# 5  Bind       Skye            DRX   247102  137401
# 6  Bind      Viper            DRX   247102  137401
# 7  Bind  Brimstone            DRX   247102  137401
# 8  Bind       Yoru            DRX   247102  137401
# 9  Bind       Raze            DRX   247102  137401
#      map   agents           team match_id game_id
# 0  Split     Jett  Natus Vincere   247102  137402
# 1  Split   Cypher  Natus Vincere   247102  137402
# 2  Split     Raze  Natus Vincere   247102  137402
# 3  Split     Skye  Natus Vincere   247102  137402
# 4  Split     Omen  Natus Vincere   247102  137402
# 5  Split     Raze            DRX   247102  137402
# 6  Split     Skye            DRX   247102  137402
# 7  Split     Omen            DRX   247102  137402
# 8  Split    Viper            DRX   247102  137402
# 9  Split  Killjoy            DRX   247102  137402
#      map     agents           team match_id game_id
# 0  Lotus    Killjoy  Natus Vincere   247102  137403
# 1  Lotus       Sova  Natus Vincere   247102  137403
# 2  Lotus     Breach  Natus Vincere   247102  137403
# 3  Lotus  Brimstone  Natus Vincere   247102  137403
# 4  Lotus       Raze  Natus Vincere   247102  137403
# 5  Lotus    Killjoy            DRX   247102  137403
# 6  Lotus       Raze            DRX   247102  137403
# 7  Lotus       Omen            DRX   247102  137403
# 8  Lotus       Fade            DRX   247102  137403
# 9  Lotus      Viper            DRX   247102  137403
# Scraping match 6 of 34.
#      map   agents             team match_id game_id
# 0  Lotus     Raze      NRG Esports   247094  137383
# 1  Lotus     Omen      NRG Esports   247094  137383
# 2  Lotus  Killjoy      NRG Esports   247094  137383
# 3  Lotus    Viper      NRG Esports   247094  137383
# 4  Lotus     Skye      NRG Esports   247094  137383
# 5  Lotus     Fade  Bilibili Gaming   247094  137383
# 6  Lotus     Raze  Bilibili Gaming   247094  137383
# 7  Lotus  Killjoy  Bilibili Gaming   247094  137383
# 8  Lotus    Viper  Bilibili Gaming   247094  137383
# 9  Lotus     Omen  Bilibili Gaming   247094  137383
#      map  agents             team match_id game_id
# 0  Split    Skye      NRG Esports   247094  137384
# 1  Split   Astra      NRG Esports   247094  137384
# 2  Split    Jett      NRG Esports   247094  137384
# 3  Split   Viper      NRG Esports   247094  137384
# 4  Split    Raze      NRG Esports   247094  137384
# 5  Split    Raze  Bilibili Gaming   247094  137384
# 6  Split   Viper  Bilibili Gaming   247094  137384
# 7  Split  Cypher  Bilibili Gaming   247094  137384
# 8  Split    Skye  Bilibili Gaming   247094  137384
# 9  Split    Omen  Bilibili Gaming   247094  137384
# Scraping match 7 of 34.
#         map     agents           team match_id game_id
# 0  Fracture    Killjoy         FNATIC   247093  137380
# 1  Fracture       Raze         FNATIC   247093  137380
# 2  Fracture       Sova         FNATIC   247093  137380
# 3  Fracture     Breach         FNATIC   247093  137380
# 4  Fracture  Brimstone         FNATIC   247093  137380
# 5  Fracture       Raze  ZETA DIVISION   247093  137380
# 6  Fracture  Brimstone  ZETA DIVISION   247093  137380
# 7  Fracture    Chamber  ZETA DIVISION   247093  137380
# 8  Fracture       Neon  ZETA DIVISION   247093  137380
# 9  Fracture     Breach  ZETA DIVISION   247093  137380
#      map   agents           team match_id game_id
# 0  Haven  Killjoy         FNATIC   247093  137381
# 1  Haven     Sova         FNATIC   247093  137381
# 2  Haven   Breach         FNATIC   247093  137381
# 3  Haven    Astra         FNATIC   247093  137381
# 4  Haven     Jett         FNATIC   247093  137381
# 5  Haven  Killjoy  ZETA DIVISION   247093  137381
# 6  Haven  Chamber  ZETA DIVISION   247093  137381
# 7  Haven    Astra  ZETA DIVISION   247093  137381
# 8  Haven     Skye  ZETA DIVISION   247093  137381
# 9  Haven     Raze  ZETA DIVISION   247093  137381
# Scraping match 8 of 34.
#      map     agents           team match_id game_id
# 0  Pearl       Kayo  Evil Geniuses   247088  137371
# 1  Pearl    Killjoy  Evil Geniuses   247088  137371
# 2  Pearl       Sova  Evil Geniuses   247088  137371
# 3  Pearl      Astra  Evil Geniuses   247088  137371
# 4  Pearl       Jett  Evil Geniuses   247088  137371
# 5  Pearl       Kayo    FUT Esports   247088  137371
# 6  Pearl      Viper    FUT Esports   247088  137371
# 7  Pearl  Brimstone    FUT Esports   247088  137371
# 8  Pearl    Killjoy    FUT Esports   247088  137371
# 9  Pearl       Jett    FUT Esports   247088  137371
#     map     agents           team match_id game_id
# 0  Bind       Raze  Evil Geniuses   247088  137372
# 1  Bind    Chamber  Evil Geniuses   247088  137372
# 2  Bind      Viper  Evil Geniuses   247088  137372
# 3  Bind  Brimstone  Evil Geniuses   247088  137372
# 4  Bind       Skye  Evil Geniuses   247088  137372
# 5  Bind      Viper    FUT Esports   247088  137372
# 6  Bind       Raze    FUT Esports   247088  137372
# 7  Bind       Kayo    FUT Esports   247088  137372
# 8  Bind       Fade    FUT Esports   247088  137372
# 9  Bind  Brimstone    FUT Esports   247088  137372
# Scraping match 9 of 34.
#      map   agents         team match_id game_id
# 0  Split    Astra    Paper Rex   247075  137350
# 1  Split     Skye    Paper Rex   247075  137350
# 2  Split     Jett    Paper Rex   247075  137350
# 3  Split     Raze    Paper Rex   247075  137350
# 4  Split    Viper    Paper Rex   247075  137350
# 5  Split     Raze  KRÜ Esports   247075  137350
# 6  Split  Chamber  KRÜ Esports   247075  137350
# 7  Split    Astra  KRÜ Esports   247075  137350
# 8  Split     Skye  KRÜ Esports   247075  137350
# 9  Split    Viper  KRÜ Esports   247075  137350
#      map   agents         team match_id game_id
# 0  Pearl    Astra    Paper Rex   247075  137351
# 1  Pearl     Skye    Paper Rex   247075  137351
# 2  Pearl  Phoenix    Paper Rex   247075  137351
# 3  Pearl     Jett    Paper Rex   247075  137351
# 4  Pearl  Killjoy    Paper Rex   247075  137351
# 5  Pearl     Jett  KRÜ Esports   247075  137351
# 6  Pearl    Viper  KRÜ Esports   247075  137351
# 7  Pearl  Killjoy  KRÜ Esports   247075  137351
# 8  Pearl   Harbor  KRÜ Esports   247075  137351
# 9  Pearl     Skye  KRÜ Esports   247075  137351
# Scraping match 10 of 34.
#      map  agents           team match_id game_id
# 0  Split    Skye  EDward Gaming   247076  137353
# 1  Split    Raze  EDward Gaming   247076  137353
# 2  Split   Viper  EDward Gaming   247076  137353
# 3  Split   Astra  EDward Gaming   247076  137353
# 4  Split    Jett  EDward Gaming   247076  137353
# 5  Split    Raze  Giants Gaming   247076  137353
# 6  Split  Breach  Giants Gaming   247076  137353
# 7  Split    Omen  Giants Gaming   247076  137353
# 8  Split  Cypher  Giants Gaming   247076  137353
# 9  Split    Skye  Giants Gaming   247076  137353
#     map     agents           team match_id game_id
# 0  Bind       Skye  EDward Gaming   247076  137354
# 1  Bind    Chamber  EDward Gaming   247076  137354
# 2  Bind  Brimstone  EDward Gaming   247076  137354
# 3  Bind      Viper  EDward Gaming   247076  137354
# 4  Bind       Raze  EDward Gaming   247076  137354
# 5  Bind       Raze  Giants Gaming   247076  137354
# 6  Bind       Skye  Giants Gaming   247076  137354
# 7  Bind     Cypher  Giants Gaming   247076  137354
# 8  Bind      Viper  Giants Gaming   247076  137354
# 9  Bind  Brimstone  Giants Gaming   247076  137354
#       map   agents           team match_id game_id
# 0  Ascent     Sova  EDward Gaming   247076  137355
# 1  Ascent  Killjoy  EDward Gaming   247076  137355
# 2  Ascent     Jett  EDward Gaming   247076  137355
# 3  Ascent     Omen  EDward Gaming   247076  137355
# 4  Ascent     Kayo  EDward Gaming   247076  137355
# 5  Ascent     Kayo  Giants Gaming   247076  137355
# 6  Ascent     Sova  Giants Gaming   247076  137355
# 7  Ascent     Jett  Giants Gaming   247076  137355
# 8  Ascent  Killjoy  Giants Gaming   247076  137355
# 9  Ascent     Omen  Giants Gaming   247076  137355
# Scraping match 11 of 34.
#      map   agents             team match_id game_id
# 0  Haven    Astra           FNATIC   247095  137386
# 1  Haven   Breach           FNATIC   247095  137386
# 2  Haven     Jett           FNATIC   247095  137386
# 3  Haven  Killjoy           FNATIC   247095  137386
# 4  Haven     Sova           FNATIC   247095  137386
# 5  Haven  Killjoy  Bilibili Gaming   247095  137386
# 6  Haven     Jett  Bilibili Gaming   247095  137386
# 7  Haven     Sova  Bilibili Gaming   247095  137386
# 8  Haven   Breach  Bilibili Gaming   247095  137386
# 9  Haven     Omen  Bilibili Gaming   247095  137386
#      map   agents             team match_id game_id
# 0  Lotus    Viper           FNATIC   247095  137387
# 1  Lotus     Raze           FNATIC   247095  137387
# 2  Lotus     Fade           FNATIC   247095  137387
# 3  Lotus  Killjoy           FNATIC   247095  137387
# 4  Lotus    Astra           FNATIC   247095  137387
# 5  Lotus    Viper  Bilibili Gaming   247095  137387
# 6  Lotus  Killjoy  Bilibili Gaming   247095  137387
# 7  Lotus     Raze  Bilibili Gaming   247095  137387
# 8  Lotus     Fade  Bilibili Gaming   247095  137387
# 9  Lotus     Omen  Bilibili Gaming   247095  137387
# Scraping match 12 of 34.
#      map   agents         team match_id game_id
# 0  Haven     Jett  Team Liquid   247103  137404
# 1  Haven  Killjoy  Team Liquid   247103  137404
# 2  Haven     Skye  Team Liquid   247103  137404
# 3  Haven     Omen  Team Liquid   247103  137404
# 4  Haven   Breach  Team Liquid   247103  137404
# 5  Haven  Killjoy         LOUD   247103  137404
# 6  Haven   Harbor         LOUD   247103  137404
# 7  Haven     Skye         LOUD   247103  137404
# 8  Haven     Jett         LOUD   247103  137404
# 9  Haven    Viper         LOUD   247103  137404
#      map   agents         team match_id game_id
# 0  Split     Raze  Team Liquid   247103  137405
# 1  Split    Astra  Team Liquid   247103  137405
# 2  Split     Skye  Team Liquid   247103  137405
# 3  Split     Jett  Team Liquid   247103  137405
# 4  Split    Viper  Team Liquid   247103  137405
# 5  Split    Astra         LOUD   247103  137405
# 6  Split     Skye         LOUD   247103  137405
# 7  Split   Breach         LOUD   247103  137405
# 8  Split  Killjoy         LOUD   247103  137405
# 9  Split     Raze         LOUD   247103  137405
# Scraping match 13 of 34.
#      map   agents             team match_id game_id
# 0  Lotus     Raze  FunPlus Phoenix   247089  137374
# 1  Lotus    Gekko  FunPlus Phoenix   247089  137374
# 2  Lotus   Harbor  FunPlus Phoenix   247089  137374
# 3  Lotus  Killjoy  FunPlus Phoenix   247089  137374
# 4  Lotus    Viper  FunPlus Phoenix   247089  137374
# 5  Lotus    Viper               T1   247089  137374
# 6  Lotus     Raze               T1   247089  137374
# 7  Lotus  Killjoy               T1   247089  137374
# 8  Lotus     Omen               T1   247089  137374
# 9  Lotus     Fade               T1   247089  137374
#     map  agents             team match_id game_id
# 0  Bind    Skye  FunPlus Phoenix   247089  137375
# 1  Bind   Viper  FunPlus Phoenix   247089  137375
# 2  Bind    Raze  FunPlus Phoenix   247089  137375
# 3  Bind    Jett  FunPlus Phoenix   247089  137375
# 4  Bind  Harbor  FunPlus Phoenix   247089  137375
# 5  Bind    Jett               T1   247089  137375
# 6  Bind   Viper               T1   247089  137375
# 7  Bind  Harbor               T1   247089  137375
# 8  Bind    Skye               T1   247089  137375
# 9  Bind   Gekko               T1   247089  137375
# Scraping match 14 of 34.
#         map     agents           team match_id game_id
# 0  Fracture  Brimstone      Paper Rex   247077  137356
# 1  Fracture       Skye      Paper Rex   247077  137356
# 2  Fracture     Breach      Paper Rex   247077  137356
# 3  Fracture       Raze      Paper Rex   247077  137356
# 4  Fracture    Killjoy      Paper Rex   247077  137356
# 5  Fracture       Jett  EDward Gaming   247077  137356
# 6  Fracture    Killjoy  EDward Gaming   247077  137356
# 7  Fracture  Brimstone  EDward Gaming   247077  137356
# 8  Fracture     Breach  EDward Gaming   247077  137356
# 9  Fracture       Skye  EDward Gaming   247077  137356
#      map   agents           team match_id game_id
# 0  Pearl     Skye      Paper Rex   247077  137357
# 1  Pearl  Killjoy      Paper Rex   247077  137357
# 2  Pearl  Phoenix      Paper Rex   247077  137357
# 3  Pearl    Astra      Paper Rex   247077  137357
# 4  Pearl     Jett      Paper Rex   247077  137357
# 5  Pearl  Killjoy  EDward Gaming   247077  137357
# 6  Pearl     Jett  EDward Gaming   247077  137357
# 7  Pearl    Viper  EDward Gaming   247077  137357
# 8  Pearl     Omen  EDward Gaming   247077  137357
# 9  Pearl     Fade  EDward Gaming   247077  137357
# Scraping match 15 of 34.
#      map   agents           team match_id game_id
# 0  Lotus  Killjoy    KRÜ Esports   247078  137359
# 1  Lotus     Raze    KRÜ Esports   247078  137359
# 2  Lotus    Viper    KRÜ Esports   247078  137359
# 3  Lotus     Omen    KRÜ Esports   247078  137359
# 4  Lotus     Skye    KRÜ Esports   247078  137359
# 5  Lotus  Killjoy  Giants Gaming   247078  137359
# 6  Lotus     Omen  Giants Gaming   247078  137359
# 7  Lotus    Viper  Giants Gaming   247078  137359
# 8  Lotus     Raze  Giants Gaming   247078  137359
# 9  Lotus     Skye  Giants Gaming   247078  137359
#      map   agents           team match_id game_id
# 0  Pearl     Jett    KRÜ Esports   247078  137360
# 1  Pearl  Killjoy    KRÜ Esports   247078  137360
# 2  Pearl    Viper    KRÜ Esports   247078  137360
# 3  Pearl     Skye    KRÜ Esports   247078  137360
# 4  Pearl   Harbor    KRÜ Esports   247078  137360
# 5  Pearl     Skye  Giants Gaming   247078  137360
# 6  Pearl     Jett  Giants Gaming   247078  137360
# 7  Pearl     Sova  Giants Gaming   247078  137360
# 8  Pearl    Astra  Giants Gaming   247078  137360
# 9  Pearl   Cypher  Giants Gaming   247078  137360
# Scraping match 16 of 34.
#     map     agents           team match_id game_id
# 0  Bind       Neon  ZETA DIVISION   247096  137389
# 1  Bind      Viper  ZETA DIVISION   247096  137389
# 2  Bind       Skye  ZETA DIVISION   247096  137389
# 3  Bind       Raze  ZETA DIVISION   247096  137389
# 4  Bind  Brimstone  ZETA DIVISION   247096  137389
# 5  Bind       Skye    NRG Esports   247096  137389
# 6  Bind    Chamber    NRG Esports   247096  137389
# 7  Bind       Raze    NRG Esports   247096  137389
# 8  Bind      Viper    NRG Esports   247096  137389
# 9  Bind  Brimstone    NRG Esports   247096  137389
#      map   agents           team match_id game_id
# 0  Haven  Killjoy  ZETA DIVISION   247096  137390
# 1  Haven  Chamber  ZETA DIVISION   247096  137390
# 2  Haven     Skye  ZETA DIVISION   247096  137390
# 3  Haven     Raze  ZETA DIVISION   247096  137390
# 4  Haven    Astra  ZETA DIVISION   247096  137390
# 5  Haven     Jett    NRG Esports   247096  137390
# 6  Haven   Harbor    NRG Esports   247096  137390
# 7  Haven    Viper    NRG Esports   247096  137390
# 8  Haven  Killjoy    NRG Esports   247096  137390
# 9  Haven     Skye    NRG Esports   247096  137390
# Scraping match 17 of 34.
#      map   agents           team match_id game_id
# 0  Pearl     Jett  Natus Vincere   247104  137407
# 1  Pearl     Sova  Natus Vincere   247104  137407
# 2  Pearl  Killjoy  Natus Vincere   247104  137407
# 3  Pearl     Kayo  Natus Vincere   247104  137407
# 4  Pearl    Astra  Natus Vincere   247104  137407
# 5  Pearl     Fade           LOUD   247104  137407
# 6  Pearl  Killjoy           LOUD   247104  137407
# 7  Pearl   Breach           LOUD   247104  137407
# 8  Pearl    Astra           LOUD   247104  137407
# 9  Pearl     Jett           LOUD   247104  137407
#       map   agents           team match_id game_id
# 0  Ascent     Fade  Natus Vincere   247104  137408
# 1  Ascent     Jett  Natus Vincere   247104  137408
# 2  Ascent  Killjoy  Natus Vincere   247104  137408
# 3  Ascent     Kayo  Natus Vincere   247104  137408
# 4  Ascent     Omen  Natus Vincere   247104  137408
# 5  Ascent     Sova           LOUD   247104  137408
# 6  Ascent     Kayo           LOUD   247104  137408
# 7  Ascent     Omen           LOUD   247104  137408
# 8  Ascent     Jett           LOUD   247104  137408
# 9  Ascent  Killjoy           LOUD   247104  137408
#     map     agents           team match_id game_id
# 0  Bind       Neon  Natus Vincere   247104  137409
# 1  Bind      Viper  Natus Vincere   247104  137409
# 2  Bind  Brimstone  Natus Vincere   247104  137409
# 3  Bind       Raze  Natus Vincere   247104  137409
# 4  Bind       Skye  Natus Vincere   247104  137409
# 5  Bind      Viper           LOUD   247104  137409
# 6  Bind       Raze           LOUD   247104  137409
# 7  Bind  Brimstone           LOUD   247104  137409
# 8  Bind       Omen           LOUD   247104  137409
# 9  Bind       Skye           LOUD   247104  137409
# Scraping match 18 of 34.
#     map     agents         team match_id game_id
# 0  Bind       Fade  FUT Esports   247090  137377
# 1  Bind       Kayo  FUT Esports   247090  137377
# 2  Bind  Brimstone  FUT Esports   247090  137377
# 3  Bind      Viper  FUT Esports   247090  137377
# 4  Bind       Raze  FUT Esports   247090  137377
# 5  Bind       Skye           T1   247090  137377
# 6  Bind       Jett           T1   247090  137377
# 7  Bind     Harbor           T1   247090  137377
# 8  Bind      Gekko           T1   247090  137377
# 9  Bind      Viper           T1   247090  137377
#      map     agents         team match_id game_id
# 0  Pearl    Killjoy  FUT Esports   247090  137378
# 1  Pearl       Kayo  FUT Esports   247090  137378
# 2  Pearl      Viper  FUT Esports   247090  137378
# 3  Pearl       Jett  FUT Esports   247090  137378
# 4  Pearl  Brimstone  FUT Esports   247090  137378
# 5  Pearl       Jett           T1   247090  137378
# 6  Pearl       Skye           T1   247090  137378
# 7  Pearl      Viper           T1   247090  137378
# 8  Pearl    Killjoy           T1   247090  137378
# 9  Pearl     Harbor           T1   247090  137378
# Scraping match 19 of 34.
#      map  agents           team match_id game_id
# 0  Split    Raze  EDward Gaming   247079  137362
# 1  Split   Viper  EDward Gaming   247079  137362
# 2  Split    Skye  EDward Gaming   247079  137362
# 3  Split    Jett  EDward Gaming   247079  137362
# 4  Split   Astra  EDward Gaming   247079  137362
# 5  Split    Skye  Giants Gaming   247079  137362
# 6  Split  Breach  Giants Gaming   247079  137362
# 7  Split    Raze  Giants Gaming   247079  137362
# 8  Split    Omen  Giants Gaming   247079  137362
# 9  Split  Cypher  Giants Gaming   247079  137362
#         map     agents           team match_id game_id
# 0  Fracture    Killjoy  EDward Gaming   247079  137363
# 1  Fracture  Brimstone  EDward Gaming   247079  137363
# 2  Fracture     Breach  EDward Gaming   247079  137363
# 3  Fracture       Skye  EDward Gaming   247079  137363
# 4  Fracture       Jett  EDward Gaming   247079  137363
# 5  Fracture       Sova  Giants Gaming   247079  137363
# 6  Fracture  Brimstone  Giants Gaming   247079  137363
# 7  Fracture     Breach  Giants Gaming   247079  137363
# 8  Fracture    Killjoy  Giants Gaming   247079  137363
# 9  Fracture       Raze  Giants Gaming   247079  137363
# Scraping match 20 of 34.
#     map     agents             team match_id game_id
# 0  Bind      Viper  Bilibili Gaming   247098  137392
# 1  Bind       Raze  Bilibili Gaming   247098  137392
# 2  Bind     Cypher  Bilibili Gaming   247098  137392
# 3  Bind       Skye  Bilibili Gaming   247098  137392
# 4  Bind  Brimstone  Bilibili Gaming   247098  137392
# 5  Bind       Raze      NRG Esports   247098  137392
# 6  Bind      Viper      NRG Esports   247098  137392
# 7  Bind  Brimstone      NRG Esports   247098  137392
# 8  Bind       Skye      NRG Esports   247098  137392
# 9  Bind    Chamber      NRG Esports   247098  137392
#       map   agents             team match_id game_id
# 0  Ascent     Omen  Bilibili Gaming   247098  137393
# 1  Ascent     Jett  Bilibili Gaming   247098  137393
# 2  Ascent     Kayo  Bilibili Gaming   247098  137393
# 3  Ascent  Killjoy  Bilibili Gaming   247098  137393
# 4  Ascent     Sova  Bilibili Gaming   247098  137393
# 5  Ascent     Kayo      NRG Esports   247098  137393
# 6  Ascent     Jett      NRG Esports   247098  137393
# 7  Ascent     Sova      NRG Esports   247098  137393
# 8  Ascent  Killjoy      NRG Esports   247098  137393
# 9  Ascent     Omen      NRG Esports   247098  137393
# Scraping match 21 of 34.
#       map   agents    team match_id game_id
# 0  Ascent  Killjoy  FNATIC   248270  137618
# 1  Ascent     Sova  FNATIC   248270  137618
# 2  Ascent     Jett  FNATIC   248270  137618
# 3  Ascent     Kayo  FNATIC   248270  137618
# 4  Ascent     Omen  FNATIC   248270  137618
# 5  Ascent     Sova    LOUD   248270  137618
# 6  Ascent     Jett    LOUD   248270  137618
# 7  Ascent  Killjoy    LOUD   248270  137618
# 8  Ascent     Omen    LOUD   248270  137618
# 9  Ascent     Kayo    LOUD   248270  137618
#      map   agents    team match_id game_id
# 0  Lotus     Raze  FNATIC   248270  137619
# 1  Lotus    Astra  FNATIC   248270  137619
# 2  Lotus     Fade  FNATIC   248270  137619
# 3  Lotus  Killjoy  FNATIC   248270  137619
# 4  Lotus    Viper  FNATIC   248270  137619
# 5  Lotus     Raze    LOUD   248270  137619
# 6  Lotus  Killjoy    LOUD   248270  137619
# 7  Lotus     Omen    LOUD   248270  137619
# 8  Lotus     Fade    LOUD   248270  137619
# 9  Lotus    Viper    LOUD   248270  137619
# Scraping match 22 of 34.
#       map   agents         team match_id game_id
# 0  Ascent    Reyna    Paper Rex   248271  137621
# 1  Ascent     Skye    Paper Rex   248271  137621
# 2  Ascent   Harbor    Paper Rex   248271  137621
# 3  Ascent     Raze    Paper Rex   248271  137621
# 4  Ascent    Viper    Paper Rex   248271  137621
# 5  Ascent     Sova  FUT Esports   248271  137621
# 6  Ascent     Kayo  FUT Esports   248271  137621
# 7  Ascent     Jett  FUT Esports   248271  137621
# 8  Ascent  Killjoy  FUT Esports   248271  137621
# 9  Ascent     Omen  FUT Esports   248271  137621
#      map     agents         team match_id game_id
# 0  Pearl       Skye    Paper Rex   248271  137622
# 1  Pearl    Killjoy    Paper Rex   248271  137622
# 2  Pearl       Jett    Paper Rex   248271  137622
# 3  Pearl    Phoenix    Paper Rex   248271  137622
# 4  Pearl      Astra    Paper Rex   248271  137622
# 5  Pearl  Brimstone  FUT Esports   248271  137622
# 6  Pearl       Jett  FUT Esports   248271  137622
# 7  Pearl    Killjoy  FUT Esports   248271  137622
# 8  Pearl      Viper  FUT Esports   248271  137622
# 9  Pearl       Kayo  FUT Esports   248271  137622
# Scraping match 23 of 34.
#      map   agents             team match_id game_id
# 0  Lotus     Raze              DRX   248272  137624
# 1  Lotus     Omen              DRX   248272  137624
# 2  Lotus  Killjoy              DRX   248272  137624
# 3  Lotus    Viper              DRX   248272  137624
# 4  Lotus     Fade              DRX   248272  137624
# 5  Lotus     Raze  Bilibili Gaming   248272  137624
# 6  Lotus    Viper  Bilibili Gaming   248272  137624
# 7  Lotus     Omen  Bilibili Gaming   248272  137624
# 8  Lotus     Fade  Bilibili Gaming   248272  137624
# 9  Lotus  Killjoy  Bilibili Gaming   248272  137624
#      map   agents             team match_id game_id
# 0  Haven    Viper              DRX   248272  137625
# 1  Haven     Jett              DRX   248272  137625
# 2  Haven     Omen              DRX   248272  137625
# 3  Haven     Skye              DRX   248272  137625
# 4  Haven  Killjoy              DRX   248272  137625
# 5  Haven     Sova  Bilibili Gaming   248272  137625
# 6  Haven     Omen  Bilibili Gaming   248272  137625
# 7  Haven   Breach  Bilibili Gaming   248272  137625
# 8  Haven     Jett  Bilibili Gaming   248272  137625
# 9  Haven  Killjoy  Bilibili Gaming   248272  137625
# Scraping match 24 of 34.
#      map   agents           team match_id game_id
# 0  Split     Skye  Evil Geniuses   248273  137627
# 1  Split    Astra  Evil Geniuses   248273  137627
# 2  Split    Viper  Evil Geniuses   248273  137627
# 3  Split     Raze  Evil Geniuses   248273  137627
# 4  Split  Chamber  Evil Geniuses   248273  137627
# 5  Split    Viper  EDward Gaming   248273  137627
# 6  Split    Astra  EDward Gaming   248273  137627
# 7  Split     Jett  EDward Gaming   248273  137627
# 8  Split     Skye  EDward Gaming   248273  137627
# 9  Split     Raze  EDward Gaming   248273  137627
#       map   agents           team match_id game_id
# 0  Ascent     Jett  Evil Geniuses   248273  137628
# 1  Ascent     Kayo  Evil Geniuses   248273  137628
# 2  Ascent     Omen  Evil Geniuses   248273  137628
# 3  Ascent  Killjoy  Evil Geniuses   248273  137628
# 4  Ascent     Sova  Evil Geniuses   248273  137628
# 5  Ascent     Sova  EDward Gaming   248273  137628
# 6  Ascent  Killjoy  EDward Gaming   248273  137628
# 7  Ascent     Jett  EDward Gaming   248273  137628
# 8  Ascent     Kayo  EDward Gaming   248273  137628
# 9  Ascent     Omen  EDward Gaming   248273  137628
#      map   agents           team match_id game_id
# 0  Pearl     Jett  Evil Geniuses   248273  137629
# 1  Pearl     Yoru  Evil Geniuses   248273  137629
# 2  Pearl     Sova  Evil Geniuses   248273  137629
# 3  Pearl  Killjoy  Evil Geniuses   248273  137629
# 4  Pearl    Astra  Evil Geniuses   248273  137629
# 5  Pearl  Killjoy  EDward Gaming   248273  137629
# 6  Pearl    Viper  EDward Gaming   248273  137629
# 7  Pearl     Skye  EDward Gaming   248273  137629
# 8  Pearl     Omen  EDward Gaming   248273  137629
# 9  Pearl     Jett  EDward Gaming   248273  137629
# Scraping match 25 of 34.
#      map  agents         team match_id game_id
# 0  Split  Cypher       FNATIC   248278  137644
# 1  Split    Raze       FNATIC   248278  137644
# 2  Split  Breach       FNATIC   248278  137644
# 3  Split    Skye       FNATIC   248278  137644
# 4  Split    Omen       FNATIC   248278  137644
# 5  Split    Omen  FUT Esports   248278  137644
# 6  Split    Skye  FUT Esports   248278  137644
# 7  Split    Kayo  FUT Esports   248278  137644
# 8  Split   Viper  FUT Esports   248278  137644
# 9  Split    Jett  FUT Esports   248278  137644
#      map   agents         team match_id game_id
# 0  Haven  Killjoy       FNATIC   248278  137645
# 1  Haven   Breach       FNATIC   248278  137645
# 2  Haven     Sova       FNATIC   248278  137645
# 3  Haven     Jett       FNATIC   248278  137645
# 4  Haven    Astra       FNATIC   248278  137645
# 5  Haven     Omen  FUT Esports   248278  137645
# 6  Haven    Gekko  FUT Esports   248278  137645
# 7  Haven   Breach  FUT Esports   248278  137645
# 8  Haven  Killjoy  FUT Esports   248278  137645
# 9  Haven     Jett  FUT Esports   248278  137645
# Scraping match 26 of 34.
#     map     agents             team match_id game_id
# 0  Bind     Cypher  Bilibili Gaming   248279  137647
# 1  Bind       Raze  Bilibili Gaming   248279  137647
# 2  Bind      Viper  Bilibili Gaming   248279  137647
# 3  Bind  Brimstone  Bilibili Gaming   248279  137647
# 4  Bind       Skye  Bilibili Gaming   248279  137647
# 5  Bind      Viper    EDward Gaming   248279  137647
# 6  Bind    Chamber    EDward Gaming   248279  137647
# 7  Bind       Raze    EDward Gaming   248279  137647
# 8  Bind  Brimstone    EDward Gaming   248279  137647
# 9  Bind       Skye    EDward Gaming   248279  137647
#      map  agents             team match_id game_id
# 0  Split    Raze  Bilibili Gaming   248279  137648
# 1  Split    Skye  Bilibili Gaming   248279  137648
# 2  Split  Cypher  Bilibili Gaming   248279  137648
# 3  Split   Viper  Bilibili Gaming   248279  137648
# 4  Split    Omen  Bilibili Gaming   248279  137648
# 5  Split    Jett    EDward Gaming   248279  137648
# 6  Split    Skye    EDward Gaming   248279  137648
# 7  Split   Astra    EDward Gaming   248279  137648
# 8  Split   Viper    EDward Gaming   248279  137648
# 9  Split    Raze    EDward Gaming   248279  137648
#      map   agents             team match_id game_id
# 0  Haven  Killjoy  Bilibili Gaming   248279  137649
# 1  Haven   Breach  Bilibili Gaming   248279  137649
# 2  Haven     Sova  Bilibili Gaming   248279  137649
# 3  Haven     Jett  Bilibili Gaming   248279  137649
# 4  Haven     Omen  Bilibili Gaming   248279  137649
# 5  Haven     Sova    EDward Gaming   248279  137649
# 6  Haven     Omen    EDward Gaming   248279  137649
# 7  Haven     Jett    EDward Gaming   248279  137649
# 8  Haven   Cypher    EDward Gaming   248279  137649
# 9  Haven   Breach    EDward Gaming   248279  137649
# Scraping match 27 of 34.
#      map   agents       team match_id game_id
# 0  Lotus     Omen       LOUD   248274  137630
# 1  Lotus     Fade       LOUD   248274  137630
# 2  Lotus     Raze       LOUD   248274  137630
# 3  Lotus  Killjoy       LOUD   248274  137630
# 4  Lotus    Viper       LOUD   248274  137630
# 5  Lotus     Jett  Paper Rex   248274  137630
# 6  Lotus     Skye  Paper Rex   248274  137630
# 7  Lotus     Raze  Paper Rex   248274  137630
# 8  Lotus    Astra  Paper Rex   248274  137630
# 9  Lotus     Omen  Paper Rex   248274  137630
#      map   agents       team match_id game_id
# 0  Split  Killjoy       LOUD   248274  137631
# 1  Split   Breach       LOUD   248274  137631
# 2  Split     Skye       LOUD   248274  137631
# 3  Split    Astra       LOUD   248274  137631
# 4  Split     Raze       LOUD   248274  137631
# 5  Split    Viper  Paper Rex   248274  137631
# 6  Split     Jett  Paper Rex   248274  137631
# 7  Split    Astra  Paper Rex   248274  137631
# 8  Split     Skye  Paper Rex   248274  137631
# 9  Split     Raze  Paper Rex   248274  137631
#      map   agents       team match_id game_id
# 0  Pearl     Jett       LOUD   248274  137632
# 1  Pearl     Fade       LOUD   248274  137632
# 2  Pearl    Astra       LOUD   248274  137632
# 3  Pearl   Breach       LOUD   248274  137632
# 4  Pearl  Killjoy       LOUD   248274  137632
# 5  Pearl     Jett  Paper Rex   248274  137632
# 6  Pearl  Phoenix  Paper Rex   248274  137632
# 7  Pearl  Killjoy  Paper Rex   248274  137632
# 8  Pearl     Skye  Paper Rex   248274  137632
# 9  Pearl    Astra  Paper Rex   248274  137632
# Scraping match 28 of 34.
#         map     agents           team match_id game_id
# 0  Fracture       Raze            DRX   248275  137633
# 1  Fracture      Viper            DRX   248275  137633
# 2  Fracture  Brimstone            DRX   248275  137633
# 3  Fracture     Breach            DRX   248275  137633
# 4  Fracture    Killjoy            DRX   248275  137633
# 5  Fracture  Brimstone  Evil Geniuses   248275  137633
# 6  Fracture       Sova  Evil Geniuses   248275  137633
# 7  Fracture     Breach  Evil Geniuses   248275  137633
# 8  Fracture    Killjoy  Evil Geniuses   248275  137633
# 9  Fracture       Raze  Evil Geniuses   248275  137633
#      map   agents           team match_id game_id
# 0  Lotus    Viper            DRX   248275  137634
# 1  Lotus     Fade            DRX   248275  137634
# 2  Lotus  Killjoy            DRX   248275  137634
# 3  Lotus     Raze            DRX   248275  137634
# 4  Lotus     Omen            DRX   248275  137634
# 5  Lotus    Astra  Evil Geniuses   248275  137634
# 6  Lotus    Viper  Evil Geniuses   248275  137634
# 7  Lotus  Killjoy  Evil Geniuses   248275  137634
# 8  Lotus     Raze  Evil Geniuses   248275  137634
# 9  Lotus     Skye  Evil Geniuses   248275  137634
# Scraping match 29 of 34.
#     map     agents           team match_id game_id
# 0  Bind  Brimstone           LOUD   248281  137653
# 1  Bind       Raze           LOUD   248281  137653
# 2  Bind       Skye           LOUD   248281  137653
# 3  Bind      Viper           LOUD   248281  137653
# 4  Bind       Omen           LOUD   248281  137653
# 5  Bind      Reyna  EDward Gaming   248281  137653
# 6  Bind       Skye  EDward Gaming   248281  137653
# 7  Bind      Viper  EDward Gaming   248281  137653
# 8  Bind       Raze  EDward Gaming   248281  137653
# 9  Bind  Brimstone  EDward Gaming   248281  137653
#       map   agents           team match_id game_id
# 0  Ascent     Omen           LOUD   248281  137654
# 1  Ascent     Sova           LOUD   248281  137654
# 2  Ascent     Kayo           LOUD   248281  137654
# 3  Ascent  Killjoy           LOUD   248281  137654
# 4  Ascent     Jett           LOUD   248281  137654
# 5  Ascent     Kayo  EDward Gaming   248281  137654
# 6  Ascent  Killjoy  EDward Gaming   248281  137654
# 7  Ascent     Sova  EDward Gaming   248281  137654
# 8  Ascent     Jett  EDward Gaming   248281  137654
# 9  Ascent     Omen  EDward Gaming   248281  137654
#      map   agents           team match_id game_id
# 0  Haven     Skye           LOUD   248281  137655
# 1  Haven  Killjoy           LOUD   248281  137655
# 2  Haven     Jett           LOUD   248281  137655
# 3  Haven    Viper           LOUD   248281  137655
# 4  Haven   Harbor           LOUD   248281  137655
# 5  Haven   Breach  EDward Gaming   248281  137655
# 6  Haven   Cypher  EDward Gaming   248281  137655
# 7  Haven     Omen  EDward Gaming   248281  137655
# 8  Haven     Jett  EDward Gaming   248281  137655
# 9  Haven     Sova  EDward Gaming   248281  137655
# Scraping match 30 of 34.
#     map     agents    team match_id game_id
# 0  Bind       Skye     DRX   248280  137650
# 1  Bind  Brimstone     DRX   248280  137650
# 2  Bind      Viper     DRX   248280  137650
# 3  Bind       Yoru     DRX   248280  137650
# 4  Bind       Raze     DRX   248280  137650
# 5  Bind      Viper  FNATIC   248280  137650
# 6  Bind       Raze  FNATIC   248280  137650
# 7  Bind    Chamber  FNATIC   248280  137650
# 8  Bind  Brimstone  FNATIC   248280  137650
# 9  Bind       Skye  FNATIC   248280  137650
#      map   agents    team match_id game_id
# 0  Haven     Jett     DRX   248280  137651
# 1  Haven     Omen     DRX   248280  137651
# 2  Haven  Killjoy     DRX   248280  137651
# 3  Haven    Viper     DRX   248280  137651
# 4  Haven     Skye     DRX   248280  137651
# 5  Haven  Killjoy  FNATIC   248280  137651
# 6  Haven     Sova  FNATIC   248280  137651
# 7  Haven     Jett  FNATIC   248280  137651
# 8  Haven    Astra  FNATIC   248280  137651
# 9  Haven   Breach  FNATIC   248280  137651
#      map   agents    team match_id game_id
# 0  Split     Omen     DRX   248280  137652
# 1  Split     Skye     DRX   248280  137652
# 2  Split     Raze     DRX   248280  137652
# 3  Split  Killjoy     DRX   248280  137652
# 4  Split    Viper     DRX   248280  137652
# 5  Split     Skye  FNATIC   248280  137652
# 6  Split   Breach  FNATIC   248280  137652
# 7  Split     Omen  FNATIC   248280  137652
# 8  Split     Raze  FNATIC   248280  137652
# 9  Split   Cypher  FNATIC   248280  137652
# Scraping match 31 of 34.
#       map   agents           team match_id game_id
# 0  Ascent    Viper      Paper Rex   248276  137636
# 1  Ascent    Reyna      Paper Rex   248276  137636
# 2  Ascent     Raze      Paper Rex   248276  137636
# 3  Ascent   Harbor      Paper Rex   248276  137636
# 4  Ascent     Skye      Paper Rex   248276  137636
# 5  Ascent     Sova  Evil Geniuses   248276  137636
# 6  Ascent     Omen  Evil Geniuses   248276  137636
# 7  Ascent     Kayo  Evil Geniuses   248276  137636
# 8  Ascent  Killjoy  Evil Geniuses   248276  137636
# 9  Ascent     Jett  Evil Geniuses   248276  137636
#     map     agents           team match_id game_id
# 0  Bind       Raze      Paper Rex   248276  137637
# 1  Bind  Brimstone      Paper Rex   248276  137637
# 2  Bind       Skye      Paper Rex   248276  137637
# 3  Bind     Harbor      Paper Rex   248276  137637
# 4  Bind      Reyna      Paper Rex   248276  137637
# 5  Bind      Viper  Evil Geniuses   248276  137637
# 6  Bind    Chamber  Evil Geniuses   248276  137637
# 7  Bind       Skye  Evil Geniuses   248276  137637
# 8  Bind       Raze  Evil Geniuses   248276  137637
# 9  Bind  Brimstone  Evil Geniuses   248276  137637
#      map   agents           team match_id game_id
# 0  Pearl    Astra      Paper Rex   248276  137638
# 1  Pearl  Killjoy      Paper Rex   248276  137638
# 2  Pearl     Skye      Paper Rex   248276  137638
# 3  Pearl  Phoenix      Paper Rex   248276  137638
# 4  Pearl     Jett      Paper Rex   248276  137638
# 5  Pearl     Jett  Evil Geniuses   248276  137638
# 6  Pearl    Astra  Evil Geniuses   248276  137638
# 7  Pearl     Yoru  Evil Geniuses   248276  137638
# 8  Pearl     Sova  Evil Geniuses   248276  137638
# 9  Pearl  Killjoy  Evil Geniuses   248276  137638
# Scraping match 32 of 34.
#      map   agents    team match_id game_id
# 0  Split     Omen  FNATIC   248282  137656
# 1  Split   Cypher  FNATIC   248282  137656
# 2  Split     Raze  FNATIC   248282  137656
# 3  Split     Skye  FNATIC   248282  137656
# 4  Split   Breach  FNATIC   248282  137656
# 5  Split  Killjoy    LOUD   248282  137656
# 6  Split   Breach    LOUD   248282  137656
# 7  Split     Skye    LOUD   248282  137656
# 8  Split    Astra    LOUD   248282  137656
# 9  Split     Raze    LOUD   248282  137656
#       map   agents    team match_id game_id
# 0  Ascent     Sova  FNATIC   248282  137657
# 1  Ascent     Jett  FNATIC   248282  137657
# 2  Ascent     Omen  FNATIC   248282  137657
# 3  Ascent  Killjoy  FNATIC   248282  137657
# 4  Ascent     Kayo  FNATIC   248282  137657
# 5  Ascent     Sova    LOUD   248282  137657
# 6  Ascent     Jett    LOUD   248282  137657
# 7  Ascent     Kayo    LOUD   248282  137657
# 8  Ascent     Omen    LOUD   248282  137657
# 9  Ascent  Killjoy    LOUD   248282  137657
#      map   agents    team match_id game_id
# 0  Haven     Sova  FNATIC   248282  137658
# 1  Haven     Jett  FNATIC   248282  137658
# 2  Haven    Astra  FNATIC   248282  137658
# 3  Haven  Killjoy  FNATIC   248282  137658
# 4  Haven   Breach  FNATIC   248282  137658
# 5  Haven     Jett    LOUD   248282  137658
# 6  Haven     Skye    LOUD   248282  137658
# 7  Haven  Killjoy    LOUD   248282  137658
# 8  Haven    Viper    LOUD   248282  137658
# 9  Haven   Harbor    LOUD   248282  137658
# Scraping match 33 of 34.
#       map   agents           team match_id game_id
# 0  Ascent     Jett  Evil Geniuses   248283  137659
# 1  Ascent     Kayo  Evil Geniuses   248283  137659
# 2  Ascent     Sova  Evil Geniuses   248283  137659
# 3  Ascent     Omen  Evil Geniuses   248283  137659
# 4  Ascent  Killjoy  Evil Geniuses   248283  137659
# 5  Ascent  Killjoy           LOUD   248283  137659
# 6  Ascent     Jett           LOUD   248283  137659
# 7  Ascent     Kayo           LOUD   248283  137659
# 8  Ascent     Sova           LOUD   248283  137659
# 9  Ascent     Omen           LOUD   248283  137659
#      map   agents           team match_id game_id
# 0  Lotus     Raze  Evil Geniuses   248283  137660
# 1  Lotus    Astra  Evil Geniuses   248283  137660
# 2  Lotus     Skye  Evil Geniuses   248283  137660
# 3  Lotus  Killjoy  Evil Geniuses   248283  137660
# 4  Lotus    Viper  Evil Geniuses   248283  137660
# 5  Lotus  Killjoy           LOUD   248283  137660
# 6  Lotus    Viper           LOUD   248283  137660
# 7  Lotus     Raze           LOUD   248283  137660
# 8  Lotus     Omen           LOUD   248283  137660
# 9  Lotus     Fade           LOUD   248283  137660
#      map   agents           team match_id game_id
# 0  Pearl     Jett  Evil Geniuses   248283  137661
# 1  Pearl     Sova  Evil Geniuses   248283  137661
# 2  Pearl    Astra  Evil Geniuses   248283  137661
# 3  Pearl  Killjoy  Evil Geniuses   248283  137661
# 4  Pearl     Yoru  Evil Geniuses   248283  137661
# 5  Pearl    Viper           LOUD   248283  137661
# 6  Pearl     Jett           LOUD   248283  137661
# 7  Pearl  Killjoy           LOUD   248283  137661
# 8  Pearl     Skye           LOUD   248283  137661
# 9  Pearl   Harbor           LOUD   248283  137661
#      map   agents           team match_id game_id
# 0  Split  Chamber  Evil Geniuses   248283  137662
# 1  Split     Skye  Evil Geniuses   248283  137662
# 2  Split    Viper  Evil Geniuses   248283  137662
# 3  Split    Astra  Evil Geniuses   248283  137662
# 4  Split     Raze  Evil Geniuses   248283  137662
# 5  Split     Raze           LOUD   248283  137662
# 6  Split     Skye           LOUD   248283  137662
# 7  Split    Astra           LOUD   248283  137662
# 8  Split   Breach           LOUD   248283  137662
# 9  Split  Killjoy           LOUD   248283  137662
#     map     agents           team match_id game_id
# 0  Bind       Skye  Evil Geniuses   248283  137663
# 1  Bind    Chamber  Evil Geniuses   248283  137663
# 2  Bind  Brimstone  Evil Geniuses   248283  137663
# 3  Bind       Raze  Evil Geniuses   248283  137663
# 4  Bind      Viper  Evil Geniuses   248283  137663
# 5  Bind       Omen           LOUD   248283  137663
# 6  Bind      Viper           LOUD   248283  137663
# 7  Bind       Raze           LOUD   248283  137663
# 8  Bind       Skye           LOUD   248283  137663
# 9  Bind  Brimstone           LOUD   248283  137663
# Scraping match 34 of 34.
#      map agents           team match_id game_id
# 0  Split  Viper      Paper Rex   248277  137639
# 1  Split   Jett      Paper Rex   248277  137639
# 2  Split   Skye      Paper Rex   248277  137639
# 3  Split  Astra      Paper Rex   248277  137639
# 4  Split   Raze      Paper Rex   248277  137639
# 5  Split   Jett  Evil Geniuses   248277  137639
# 6  Split   Raze  Evil Geniuses   248277  137639
# 7  Split  Astra  Evil Geniuses   248277  137639
# 8  Split   Skye  Evil Geniuses   248277  137639
# 9  Split  Viper  Evil Geniuses   248277  137639
#       map   agents           team match_id game_id
# 0  Ascent    Reyna      Paper Rex   248277  137640
# 1  Ascent     Kayo      Paper Rex   248277  137640
# 2  Ascent     Raze      Paper Rex   248277  137640
# 3  Ascent   Harbor      Paper Rex   248277  137640
# 4  Ascent    Viper      Paper Rex   248277  137640
# 5  Ascent     Kayo  Evil Geniuses   248277  137640
# 6  Ascent  Killjoy  Evil Geniuses   248277  137640
# 7  Ascent     Sova  Evil Geniuses   248277  137640
# 8  Ascent     Jett  Evil Geniuses   248277  137640
# 9  Ascent     Omen  Evil Geniuses   248277  137640
#     map     agents           team match_id game_id
# 0  Bind     Breach      Paper Rex   248277  137641
# 1  Bind  Brimstone      Paper Rex   248277  137641
# 2  Bind       Yoru      Paper Rex   248277  137641
# 3  Bind       Skye      Paper Rex   248277  137641
# 4  Bind       Raze      Paper Rex   248277  137641
# 5  Bind       Raze  Evil Geniuses   248277  137641
# 6  Bind      Viper  Evil Geniuses   248277  137641
# 7  Bind    Chamber  Evil Geniuses   248277  137641
# 8  Bind       Skye  Evil Geniuses   248277  137641
# 9  Bind  Brimstone  Evil Geniuses   248277  137641
#      map   agents           team match_id game_id
# 0  Lotus     Raze      Paper Rex   248277  137642
# 1  Lotus    Astra      Paper Rex   248277  137642
# 2  Lotus     Skye      Paper Rex   248277  137642
# 3  Lotus     Jett      Paper Rex   248277  137642
# 4  Lotus     Omen      Paper Rex   248277  137642
# 5  Lotus    Astra  Evil Geniuses   248277  137642
# 6  Lotus     Raze  Evil Geniuses   248277  137642
# 7  Lotus  Killjoy  Evil Geniuses   248277  137642
# 8  Lotus     Skye  Evil Geniuses   248277  137642
# 9  Lotus    Viper  Evil Geniuses   248277  137642

# %%
tournament_df.to_csv('valorant_champions_2023_agent_picks.csv')

# %%
df = pd.read_csv('valorant_champions_2023_agent_picks.csv')

# %%
df['match_id'] = df['match_id'].astype('str')
df['game_id'] = df['game_id'].astype('str')

# %%
agent_colors = {'Viper':'#2A4334',
                'Breach':'#8B4C31',
                'Astra': '#7E24D6',
                'Neon': '#566AAF',
                'Sova': '#223773',
                'Killjoy': '#F5CE2C',
                'Raze': '#F8A83E',
                'Fade': '#1E1F2C',
                'Omen': '#7577AF',
                'Chamber': '#A77E58',
                'Skye': '#628C66',
                'Brimstone': '#7F3319',
                'Kayo': '#13208F',
                'Jett': '#B7D2DA',
                'Harbor': '#0C8C74',
                'Gekko': '#C2ED57',
                'Sage': '#D9CFD8',
                'Yoru': '#3D498D',
                'Cypher': '#9B664B',
                'Phoenix': '#E58B47',
                'Reyna': '#7B3675'}

# %%
df['color'] = df['agents'].map(agent_colors)

# %%
df.head()
# Out:
#    Unnamed: 0       map  agents         team match_id game_id    color
# 0           0  Fracture   Viper  Team Liquid   247100  137395  #2A4334
# 1           1  Fracture  Breach  Team Liquid   247100  137395  #8B4C31
# 2           2  Fracture   Astra  Team Liquid   247100  137395  #7E24D6
# 3           3  Fracture    Neon  Team Liquid   247100  137395  #566AAF
# 4           4  Fracture    Sova  Team Liquid   247100  137395  #223773

# %% [markdown]
# # Dashboard

# %%
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as pyo
import dash
from dash import dcc
from dash import html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output

# %% [markdown]
# ## Styles

# %%
SIDEBAR_STYLE = {
    'position': 'fixed',
    'top': 0,
    'left': 0,
    'bottom': 0,
    'width': '30%',
    'padding': '1rem 1rem 2rem',
    'background-color': '#0A0E13',
    'margin-right': '15px',
    'color': '#FFFFFF',
    'font-family': 'arial'
}

GRAPH_STYLE = {'width': '68.2%',  
               'position': 'fixed', 
               'height': '100%', 
               'top': 0, 
               'bottom': 0, 
               'right': 0
               }

PLOT_LAYOUT = go.Layout(title = dict(text = 'Valorant Champions 2023 - Agent Selection', font = dict(size = 20)),
                   xaxis = {'title': 'Agent Name', 'categoryorder': 'total descending'},
                   yaxis = {'title': 'Pick Count', 'gridcolor': '#FFFFFF'},
                   barmode = 'group',
                   plot_bgcolor = '#0A0E13',
                   paper_bgcolor = '#0A0E13',
                   font_color = '#FFFFFF',
                   font_family = 'Arial')

# %% [markdown]
# ## Dashboard Components

# %%
#Plotly Chart
data = [go.Histogram(x = df['agents'], y = df['game_id'])]
layout = go.Layout(title = 'Valorant Champions 2023 - Agent Pickrate',
                   xaxis = {'title': 'Agent Name', 'categoryorder': 'total descending'},
                   yaxis = {'title': 'Pick Count'},
                   barmode = 'group')

# %%
map_options = [{'label': loc, 'value': loc} for loc in df['map'].unique()]
map_options.append({'label': 'All Maps', 'value': 'All Maps'})

# %%
#Map Select
dropdown = dcc.Dropdown(id = 'map-picker', options = map_options, value = 'All Maps', style = {'color':'#000000'})

# %%
#Image 
img = '/assets/valorant-logo_resized.png'

# %%
#Sidebar
sidebar = html.Div([
    html.Img(src=img),
    html.H2('Filters'),
    html.Hr(),
    html.P('Select A Map:'),
    dbc.Nav(
        [dropdown],
        vertical = True,
        pills = True)
    ],
    style = SIDEBAR_STYLE
)

# %% [markdown]
# ## Run Dashboard

# %%
app = dash.Dash()

# %%
app.layout = html.Div(children = [
                dbc.Row(
                    [dbc.Col(sidebar),
                    dbc.Col(dcc.Graph(id = 'bar', style = GRAPH_STYLE))
                    ])
    ]
)

if __name__ == '__main__':
    app.run_server(jupyter_mode = 'external', debug = 'True')
# Out:
# Dash app running on http://127.0.0.1:8050/

# %%
@app.callback(Output('bar','figure'), [Input('map-picker','value')])
def update_map(selected_map):
    if selected_map == 'All Maps' or selected_map == None:
        data = [go.Histogram(x = df['agents'],
                            y = df['game_id'],
                            marker = {'color':'#FF4655'})]
                        
    else:
        filtered_df = df.loc[df['map'] == selected_map]
        data = [go.Histogram(x = filtered_df['agents'],
                        y = filtered_df['game_id'],
                            marker = {'color':'#FF4655'})]
        
    fig = {'data': data,
           'layout': PLOT_LAYOUT}
    
    return fig
